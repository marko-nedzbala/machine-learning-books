# %%
from itertools import product
from collections import defaultdict

# %%
possible_children = ['Boy', 'Girl']
sample_space = set()

sample_space_efficient = set(product(possible_children, repeat=4))
# assert sample_space == sample_space_efficient
sample_space == sample_space_efficient
# Out:
# False

# %%
def generate_coin_sample_space(num_flips=10):
    weighted_sample_space = defaultdict(int)
    for coin_flips in product(['Heads', 'Tails'], repeat=num_flips):
        heads_count = len([outcome for outcome in coin_flips if outcome == 'Heads'])
        weighted_sample_space[heads_count] += 1
    return weighted_sample_space

weighted_sample_space = generate_coin_sample_space()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 10
#       6     return weighted_sample_space
#       8 weighted_sample_space = generate_coin_sample_space()
# ---> 10 prob = compute_event_probability(lambda x: is_in_interval(x, 8, 10), weighted_sample_space)
#      11 print(f'Probability of observing more than 7 heads is {prob}')
#
# NameError: name 'compute_event_probability' is not defined
